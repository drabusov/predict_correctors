# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./results/betabeat_and_correctors.csv")

# %%
df.head()
# Out:
#    stopband_initial  stopband_final  success  K1NL_S19QS1J  K1NL_S1DQS1J  \
# 0          0.012104        0.006324     True     -0.051045     -0.136092
# 1          0.016742        0.006214     True     -0.215822      0.175322
# 2          0.055995        0.015997     True     -0.019639      0.322355
# 3          0.030164        0.012602     True      0.534677     -0.376969
# 4          0.003421        0.003015     True     -0.030049      0.057324
#
#    K1NL_S29QS1J  K1NL_S2DQS1J  K1NL_S39QS1J  K1NL_S3DQS1J  K1NL_S49QS1J  ...  \
# 0      1.151088     -0.733696  7.483259e-02     -0.263654      0.146610  ...
# 1     -0.093314      0.975223  5.854220e-01     -0.773475     -0.775836  ...
# 2      1.743440     -0.025644 -2.075246e-01     -0.752784      0.725741  ...
# 3      0.120730      0.503753 -5.730788e-01     -0.773201     -0.699929  ...
# 4      0.994834      0.050000 -1.083506e-12      1.169834      0.044834  ...
#
#     s65dx1v    s66dx1v   s67dx1v    s68dx1v    s69dx1v    s6adx1v   s6bdx1v  \
# 0  5.771377  18.756994  5.760479  18.788261  18.670229  18.797554  5.738992
# 1  5.771377  18.756994  5.760479  18.788261  18.670229  18.797554  5.738992
# 2  5.771377  18.756994  5.760479  18.788261  18.670229  18.797554  5.738992
# 3  5.771377  18.756994  5.760479  18.788261  18.670229  18.797554  5.738992
# 4  5.771377  18.756994  5.760479  18.788261  18.670229  18.797554  5.738992
#
#      s6cdx1v    s6ddx1v   s6edx1v
# 0  18.781166  18.701327  5.811594
# 1  18.781166  18.701327  5.811594
# 2  18.781166  18.701327  5.811594
# 3  18.781166  18.701327  5.811594
# 4  18.781166  18.701327  5.811594
#
# [5 rows x 203 columns]

# %%
df.describe()
# Out:
#        stopband_initial  stopband_final  K1NL_S19QS1J  K1NL_S1DQS1J  \
# count       9901.000000     9901.000000   9901.000000   9901.000000
# mean           0.042149        0.015868     -0.011038     -0.026608
# std            0.048611        0.016567      0.529348      0.566813
# min            0.002117        0.002119     -4.504957     -4.958169
# 25%            0.016455        0.007298     -0.167475     -0.170824
# 50%            0.023454        0.008830     -0.012529     -0.015241
# 75%            0.038407        0.014118      0.132122      0.139106
# max            0.354746        0.101279      4.417325      5.030000
#
#        K1NL_S29QS1J  K1NL_S2DQS1J  K1NL_S39QS1J  K1NL_S3DQS1J  K1NL_S49QS1J  \
# count   9901.000000   9901.000000  9.901000e+03   9901.000000   9901.000000
# mean       0.433705      0.154760  3.872913e-02     -0.036615     -0.109909
# std        0.901331      0.810403  7.416117e-01      0.667915      0.627549
# min       -3.301607     -3.083342 -3.573183e+00     -3.983085     -3.314783
# 25%       -0.157940     -0.327550 -3.949298e-01     -0.398045     -0.437261
# 50%        0.368420      0.057759 -9.972328e-12     -0.022223     -0.050964
# 75%        1.051921      0.648471  4.252134e-01      0.281419      0.202887
# max        4.537693      4.001160  3.837884e+00      3.711757      3.277929
#
#        K1NL_S4DQS1J  ...       s65dx1v       s66dx1v       s67dx1v  \
# count   9901.000000  ...  9.901000e+03  9.901000e+03  9.901000e+03
# mean      -0.176739  ...  5.771377e+00  1.875699e+01  5.760479e+00
# std        0.623458  ...  8.438121e-14  7.496604e-13  1.152026e-12
# min       -3.974869  ...  5.771377e+00  1.875699e+01  5.760479e+00
# 25%       -0.497336  ...  5.771377e+00  1.875699e+01  5.760479e+00
# 50%       -0.093556  ...  5.771377e+00  1.875699e+01  5.760479e+00
# 75%        0.143190  ...  5.771377e+00  1.875699e+01  5.760479e+00
# max        2.974384  ...  5.771377e+00  1.875699e+01  5.760479e+00
#
#             s68dx1v       s69dx1v       s6adx1v       s6bdx1v       s6cdx1v  \
# count  9.901000e+03  9.901000e+03  9.901000e+03  9.901000e+03  9.901000e+03
# mean   1.878826e+01  1.867023e+01  1.879755e+01  5.738992e+00  1.878117e+01
# std    4.096486e-12  4.689819e-12  1.353652e-12  1.439810e-12  2.842314e-14
# min    1.878826e+01  1.867023e+01  1.879755e+01  5.738992e+00  1.878117e+01
# 25%    1.878826e+01  1.867023e+01  1.879755e+01  5.738992e+00  1.878117e+01
# 50%    1.878826e+01  1.867023e+01  1.879755e+01  5.738992e+00  1.878117e+01
# 75%    1.878826e+01  1.867023e+01  1.879755e+01  5.738992e+00  1.878117e+01
# max    1.878826e+01  1.867023e+01  1.879755e+01  5.738992e+00  1.878117e+01
#
#             s6ddx1v       s6edx1v
# count  9.901000e+03  9.901000e+03
# mean   1.870133e+01  5.811594e+00
# std    2.110419e-12  1.303024e-12
# min    1.870133e+01  5.811594e+00
# 25%    1.870133e+01  5.811594e+00
# 50%    1.870133e+01  5.811594e+00
# 75%    1.870133e+01  5.811594e+00
# max    1.870133e+01  5.811594e+00
#
# [8 rows x 202 columns]

# %%
# all corrections converged in local mins
df["success"].unique()
# Out:
# array([ True])

# %% [markdown]
# ## optimization can return the values which make the lattice worse

# %%
df["ratio"] = df["stopband_final"] / df["stopband_initial"]

# %%
plt.plot(df["ratio"])
plt.xlabel("object index")
plt.ylabel("optimization score")
plt.axhline(1., c="r")

# %%
df = df[df["ratio"].le(0.999)]

print(f"dataset length is {len(df)}")
# Out:
# dataset length is 9760

# %% [markdown]
# ### drop features with data leakage
# before the optimization values of final stop band cannot be known
# <br>the column success is the info from the future (successful convergence)

# %%
leakage = ["success", "ratio", "stopband_final"]
df = df.drop(leakage, axis=1)

# %% [markdown]
# ## Clustering
# if errorsets are close, the resulting optimal values are close as well
# ### the set of correctors (k1nl) is the target

# %%
target_cols = [name for name in df.columns if "k1nl" in name.lower()]

Y = df[target_cols]
X = df.copy().drop(target_cols, axis=1)

# %%
scaler_x = StandardScaler()
scaler_y = StandardScaler()

x_data = scaler_x.fit_transform(X)
y_data = scaler_y.fit_transform(Y)

X_scaled = pd.DataFrame(x_data, columns = X.columns)
Y_scaled = pd.DataFrame(y_data, columns=target_cols)

X_scaled.index = X.index
Y_scaled.index = Y.index

d_out = {
    'X':X_scaled, 
    'Y':Y_scaled,
    'X_initial':X,
    'Y_initial':Y,
    'scaler_x':scaler_x,
    'scaler_y':scaler_y
}

pickle.dump(d_out, open("./results/dataset_scaled.p", "wb"))

# %%
def clustering_score(df_target, df_cluster):
    columns = df_target.columns.tolist()
    df = df_cluster.join(df_target)
    out = []
    for name in columns:
        mse = np.std(df.groupby("Cluster")[name].transform("median") - df[name])**2
        out.append(mse)
    return np.max(df_target) / np.sqrt(np.mean(out))

# %%
d = {}
for i in range(2,30):
    X_cluster = X_scaled.copy()
    kmeans = KMeans(n_clusters=i, n_init=15)
    X_cluster["Cluster"] = kmeans.fit_predict(X_scaled)
    X_cluster["Cluster"] = X_cluster["Cluster"].astype('category')
    
    score = clustering_score(Y, X_cluster)
    
    print(f"n_clusters {i}, score = {np.mean(score)}")
    d[i] = np.mean(score)
# Out:
# n_clusters 2, score = 7.089336210639545
# n_clusters 3, score = 7.088896004328607
# n_clusters 4, score = 7.087984350298581
# n_clusters 5, score = 7.092237454174692
# n_clusters 6, score = 7.094059605286129
# n_clusters 7, score = 7.094490709545862
# n_clusters 8, score = 7.0950969084526525
# n_clusters 9, score = 7.0977487212461865
# n_clusters 10, score = 7.098149118080168
# n_clusters 11, score = 7.09920078667669
# n_clusters 12, score = 7.0992748452751115
# n_clusters 13, score = 7.097475515748106
# n_clusters 14, score = 7.096549069873688
# n_clusters 15, score = 7.0974876647873275
# n_clusters 16, score = 7.0987249025087955
# n_clusters 17, score = 7.098668046236835
# n_clusters 18, score = 7.0946552077094465
# n_clusters 19, score = 7.0988720328453105
# n_clusters 20, score = 7.0989528372122805
# n_clusters 21, score = 7.0990246713011445
# n_clusters 22, score = 7.099411392022849
# n_clusters 23, score = 7.109520486869836
# n_clusters 24, score = 7.107536962492709
# n_clusters 25, score = 7.107611211467102
# n_clusters 26, score = 7.109773883623855
# n_clusters 27, score = 7.108981067644766
# n_clusters 28, score = 7.106483929537298
# n_clusters 29, score = 7.123308861798429

# %%
plt.plot(d.keys(), d.values())

plt.xlabel("number of clusters")
plt.ylabel("signal to noise")
# Out:
# Text(0, 0.5, 'signal to noise')

# %% [markdown]
# ## trade-off between n_clusters and signal / noise

# %%
n_clusters = 17

kmeans = KMeans(n_clusters=n_clusters, n_init=50)
X_scaled["Cluster"] = kmeans.fit_predict(X_scaled)
X_scaled["Cluster"] = X_scaled["Cluster"].astype('category')

# tmp dataframe with the target-vector
df = X_scaled.join(Y)

for name in target_cols:
    median = df.groupby("Cluster")[name].transform("median")
    X_scaled[f"{name}_median"] = median #(median - np.mean(median)) / np.std(median)

# %%
X_scaled.head()
# Out:
#    stopband_initial   s11dx1h   s12dx1h  s13dibpmh   s13dx1h   s14dx1h  \
# 0          0.954444  0.575400 -0.084995  -1.596671 -0.825951  1.337614
# 1         -0.354104  0.355494 -0.139282  -0.513892  0.008571  0.057837
# 2         -0.422238  0.033347  0.106313  -0.025644 -0.027474  0.109435
# 3          0.816596 -0.810678  1.156897  -0.288955 -1.302123  1.213713
# 4         -0.620469  0.528466 -0.708998  -0.136076  0.691925 -0.757812
#
#     s15dx1h   s16dx1h   s17dx1h   s18dx1h  ...  K1NL_S29QS1J_median  \
# 0 -1.445127  1.535842 -1.843521  1.203337  ...             0.005941
# 1 -0.095165  0.296405 -0.314731  0.510401  ...             0.060391
# 2 -0.157813  0.163785 -0.171849 -0.011814  ...             0.060391
# 3 -1.116373  0.372150 -1.182009  0.148733  ...             0.032634
# 4  0.691377  0.009021  0.356939  0.477877  ...             0.017902
#
#    K1NL_S2DQS1J_median  K1NL_S39QS1J_median  K1NL_S3DQS1J_median  \
# 0             0.009678            -0.012960            -0.015192
# 1             0.034387             0.006965            -0.007572
# 2             0.034387             0.006965            -0.007572
# 3             0.041377            -0.024811            -0.023496
# 4             0.025259             0.006184            -0.001891
#
#    K1NL_S49QS1J_median  K1NL_S4DQS1J_median  K1NL_S59QS1J_median  \
# 0            -0.023499            -0.025106            -0.367677
# 1            -0.027875            -0.032876            -0.026966
# 2            -0.027875            -0.032876            -0.026966
# 3            -0.058370            -0.070906             0.726769
# 4            -0.010258            -0.006363            -0.000113
#
#    K1NL_S5DQS1J_median  K1NL_S69QS1J_median  K1NL_S6DQS1J_median
# 0            -0.141728            -0.009308            -0.013354
# 1             0.449555            -0.008282            -0.014707
# 2             0.449555            -0.008282            -0.014707
# 3            -0.398898             0.221176             0.016540
# 4             0.019596             0.002877            -0.000648
#
# [5 rows x 190 columns]

# %% [markdown]
# ## Pipeline algorithm
# get measurement -> clean data (if noise added) -> data normalization -> get cluster values -> initial guess (k1nl_median)

# %%
d_out = {
    'kmeans':kmeans, # to transform test data
    'X':X_scaled, 
    'Y':Y_scaled,
    'X_initial':X,
    'Y_initial':Y,
    'scaler_x':scaler_x,
    'scaler_y':scaler_y}

pickle.dump(d_out, open("./results/dataset_clustered.p", "wb"))
